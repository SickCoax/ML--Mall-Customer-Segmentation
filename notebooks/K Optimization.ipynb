# %% [markdown]
# # K Optimization

# %%
# Imports

import os
import sys

sys.path.append(os.path.abspath("../src"))
sys.path.append(os.path.abspath(".."))

from preprocessing import get_X
import pandas as pd
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering

# %%
# Data Load

df = pd.read_csv("../dataset/Mall_Customers.csv")
X = get_X(df)

X
# Out:
#      Annual Income (k$)  Spending Score (1-100)       Age
# 0             -1.738999               -0.434801 -1.424569
# 1             -1.738999                1.195704 -1.281035
# 2             -1.700830               -1.715913 -1.352802
# 3             -1.700830                1.040418 -1.137502
# 4             -1.662660               -0.395980 -0.563369
# ..                  ...                     ...       ...
# 195            2.268791                1.118061 -0.276302
# 196            2.497807               -0.861839  0.441365
# 197            2.497807                0.923953 -0.491602
# 198            2.917671               -1.250054 -0.491602
# 199            2.917671                1.273347 -0.635135
#
# [200 rows x 3 columns]

# %%
# Dandogram

Z = linkage(X, method="ward")

plt.figure(figsize=(10,5))
dendrogram(Z)
plt.show()

# %%
# Silhouette Score Graph

score = []

for k in range(2,11) :
    
    model = AgglomerativeClustering(
    n_clusters = k ,
    linkage = "ward"
    )

    model.fit(X)
    
    label = model.labels_
    score.append(silhouette_score(X , label))

# %%
# Silhouette Score plot

plt.plot(
    range(2,11) ,
    score
)
plt.xlabel("no of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Score Curve")
plt.grid()
plt.show()

# %% [markdown]
# # Final Verdict
# # --------------------------------------------------------------------------------------
# # After visualizing EDA plots and checking silhouette score , the best and optimal k can be 5 or 6 , so selecting k = 6 as it has more score
